# %% [markdown]
# # Importing Modules in Python: Modules and Packages
# In Python, modules and packages help organize and reuse code. Here's a comprehensive guide on how to import them.

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi
print(sqrt(16))
print(sqrt(25))
print(pi)
# Out:
# 4.0
# 5.0
# 3.141592653589793

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import *
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
#how to create own package and how to used it 
from package.math import addition
print(addition(2, 3))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[25], line 2
#       1 #how to create own package and how to used it
# ----> 2 from package.math import addition
#       3 print(addition(2, 3))
#
# ImportError: cannot import name 'addition' from 'package.math' (/home/pc-1/Desktop/python/5-Modules/package/math.py)

# %%
from package import math
math.addition(2,3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 from package import math
# ----> 2 math.addition(2,3)
#
# AttributeError: module 'package.math' has no attribute 'addition'

# %% [markdown]
# # Conclusion
# Importing modules and packages in Python allows you to organize your code, reuse functionalities, and keep your projects clean and manageable. By understanding how to import modules, specific functions, and use relative imports within packages, you can structure your Python applications more effectively.
